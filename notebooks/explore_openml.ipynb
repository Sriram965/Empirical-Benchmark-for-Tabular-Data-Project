# %%
import pandas as pd

df = pd.read_csv("../results/excluded_datasets.csv")
print(df["exclusion_reason"].value_counts())
# Out:
# exclusion_reason
# too_few_samples;                       28
# too_few_samples; has_missing_data;      6
# too_few_samples; high_dimensional;      5
# has_missing_data;                       3
# high_dimensional;                       2
# Name: count, dtype: int64
